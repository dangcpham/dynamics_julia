# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p,q = np.genfromtxt("output/pendulum_mod_euler.out", unpack=True)

# %%
plt.plot(p,q, "k", linewidth=0.1)
plt.xlim(-np.pi, np.pi)
plt.ylim(0, 2*np.pi)
# Out:
# (0, 6.283185307179586)

# %%
p,q = np.genfromtxt("output/pendulum_leapfrog.out", unpack=True)

# %%
plt.plot(p,q, "k", linewidth=0.1)
plt.xlim(-np.pi, np.pi)
plt.ylim(0, 2*np.pi)
# Out:
# (0, 6.283185307179586)

# %%
p,q = np.genfromtxt("output/pendulum_SS3.out", unpack=True)

# %%
plt.plot(p,q, "k", linewidth=0.1)
plt.xlim(-np.pi, np.pi)
plt.ylim(0, 2*np.pi)
# Out:
# (0, 6.283185307179586)
